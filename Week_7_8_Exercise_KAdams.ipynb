# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import Datasets
df_crime = pd.read_csv('crimerates-by-state-2005.csv')
df_house = pd.read_csv('Housing_Data.csv')
df_life = pd.read_excel ('Life_Expectancy_World.xlsx')

# %%
# Scatterplot
#df_house.plot.scatter(x = 'GrLivArea', y = 'SalePrice')
plt.scatter(df_house.GrLivArea, df_house.SalePrice)
plt.xlabel("Ground Living Area (Square Feet)", size=12)
plt.ylabel("Sale Price ($ USD)", size=12)
plt.title("Sale Price and Ground Living Area Housing Data", size=12)
# Out:
# Text(0.5, 1.0, 'Sale Price and Ground Living Area Housing Data')

# %%
# Bubble Chart
plt.scatter('Birth Rate', 'Life Expectancy',
             s='GDP',
             alpha=0.5, data=df_life)
plt.xlabel("Birth Rate", size=12)
plt.ylabel("Life Expectancy", size=12)
plt.title("Birth Rate, Life Expectancy and GDP", size=12)
# Out:
# Text(0.5, 1.0, 'Birth Rate, Life Expectancy and GDP')

# %%
# Density Plot Chart
# https://www.geeksforgeeks.org/density-plots-with-pandas-in-python/
# Density Plot is a type of data visualization tool. It is a variation of the histogram that uses ‘kernel smoothing’ 
# while plotting the values. It is a continuous and smooth version of a histogram inferred from a data.
df_crime.murder.plot.density(color='green')
plt.title('Density of Murders in the USA')
plt.show()
